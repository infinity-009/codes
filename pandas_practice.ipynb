# %%
import pandas as pd

# %% [markdown]
# ## Read from HTML

# %%
# # The original code would be:
# # df = pd.read_html("https://www.dataquest.io/cheat-sheet/pandas-cheat-sheet/")

# # However, that URL doesn't contain traditional HTML tables.
# # Here's how to use read_html with proper headers to handle HTTP 403:

# import urllib.request

# headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
# req = urllib.request.Request("https://github.com/guipsamora/pandas_exercises/tree/master", headers=headers)

# with urllib.request.urlopen(req) as response:
#     html_content = response.read()

# # For a URL with tables, you would do:
# df = pd.read_html(html_content)  # This returns a list of DataFrames, one for each table

# print("Code to read HTML tables with proper headers:")
# print("df = pd.read_html('URL')  # with headers if needed")

# %% [markdown]
# ## read from CLipBoard

# %%
# try:
#     # Read data from clipboard with flexible parsing
#     data = pd.read_clipboard(sep=None, engine='python', on_bad_lines="skip")
#     print("✓ Data loaded from clipboard successfully!")
#     print(f"\nShape: {data.shape}")
#     print(f"Columns: {list(data.columns)}")
#     print(f"\nFirst few rows:")
#     print(data.head())
# except Exception as e:
#     print(f"✗ Error: {e}")
#     print("\nTroubleshooting:")
#     print("1. Make sure you copied data to your clipboard")
#     print("2. Try copying as CSV or tab-separated values")
#     print("3. If still issues, paste the raw text and I'll help parse it")

# %% [markdown]
# ## Read from json

# %%
# json_data={
#     "name":["malli"],
#     "mail":["reddy@g.com"],
#     "age":[60]
# }

# df = pd.DataFrame(json_data)
# print("DataFrame:")
# print(df)
# print("\n" + "="*60 + "\n")

# # METHOD 1: iloc (integer location) - returns Series
# print("1. df.iloc[0] - Returns Series:")
# print(df.iloc[0])
# print(type(df.iloc[0]))

# print("\n" + "="*60 + "\n")

# # METHOD 2: loc (label location) - returns Series
# print("2. df.loc[0] - Returns Series:")
# print(df.loc[0])

# print("\n" + "="*60 + "\n")

# # METHOD 3: iloc with list conversion
# print("3. df.iloc[0].tolist() - Convert to list:")
# row_as_list = df.iloc[0].tolist()
# print(row_as_list)
# print(type(row_as_list))

# print("\n" + "="*60 + "\n")

# # METHOD 4: df.values[index] - Returns numpy array
# print("4. df.values[0] - Returns numpy array:")
# print(df.values[0])
# print(type(df.values[0]))
# print("Convert to list:", df.values[0].tolist())

# print("\n" + "="*60 + "\n")

# # METHOD 5: df.iloc[index].values - Returns numpy array
# print("5. df.iloc[0].values - Returns numpy array:")
# print(df.iloc[0].values)
# print(type(df.iloc[0].values))
# print("Convert to list:", list(df.iloc[0].values))

# print("\n" + "="*60 + "\n")

# # METHOD 6: df.iloc[index].to_dict() - Convert to dict
# print("6. df.iloc[0].to_dict() - Convert to dictionary:")
# row_as_dict = df.iloc[0].to_dict()
# print(row_as_dict)

# print("\n" + "="*60 + "\n")

# # METHOD 7: df.iloc[index].to_list() - (newer pandas)
# print("7. df.iloc[0].to_list() - Convert to list:")
# print(df.iloc[0].to_list())

# print("\n" + "="*60 + "\n")

# # METHOD 8: list(df.iloc[index]) - Direct list conversion
# print("8. list(df.iloc[0]) - Direct list conversion:")
# print(list(df.iloc[0]))

# print("\n" + "="*60 + "\n")

# # SUMMARY TABLE
# print("SUMMARY - Different Ways to Get Row 0:")
# print(f"df.iloc[0] -> {type(df.iloc[0]).__name__}")
# print(f"df.iloc[0].tolist() -> {type(df.iloc[0].tolist()).__name__}")
# print(f"df.values[0] -> {type(df.values[0]).__name__}")
# print(f"df.iloc[0].to_dict() -> {type(df.iloc[0].to_dict()).__name__}")

# %%
import pandas as pd

# Create sample DataFrame with multiple rows
data = {
    "name": ["malli", "john", "sara", "mike", "lisa"],
    "email": ["malli@g.com", "john@g.com", "sara@g.com", "mike@g.com", "lisa@g.com"],
    "age": [60, 25, 30, 35, 28]
}

df=pd.DataFrame(data)
print("Original DataFrame:")
print(df)
print("\n" + "="*70 + "\n")

# %%
# ===== METHOD 12: Sample rows =====
print("METHOD 12: df.sample(n=2) - Get random 2 rows:")
print(df.sample(5))
print("\n" + "="*70 + "\n")

# %%
# # ===== METHOD 1: iloc (integer location) =====
# print("METHOD 1: df.iloc[0:3] - Extract rows 0-2 as DataFrame:")
# result1 = df.iloc[0:3]
# print(result1)
# print(f"Type: {type(result1).__name__}")
# print("\n" + "="*70 + "\n")

# # ===== METHOD 2: loc (label location) =====
# print("METHOD 2: df.loc[0:2] - Extract rows with labels 0-2 (inclusive):")
# result2 = df.loc[0:2]
# print(result2)
# print(f"Type: {type(result2).__name__}")
# print("\n" + "="*70 + "\n")

# # ===== METHOD 3: Multiple rows with list of indices =====
# print("METHOD 3: df.iloc[[0, 2, 4]] - Extract rows by list of indices:")
# result3 = df.iloc[[0, 2, 4]]
# print(result3)
# print("\n" + "="*70 + "\n")

# # ===== METHOD 4: Extract rows to list of lists =====
# print("METHOD 4: df.iloc[0:3].values - Get rows as numpy array (convert to list):")
# result4 = df.iloc[0:3].values.tolist()
# print(result4)
# print(f"Type: {type(result4).__name__}")
# print("\n" + "="*70 + "\n")

# # ===== METHOD 5: Extract rows to list of dicts =====
# print("METHOD 5: df.iloc[0:3].to_dict('records') - Get rows as list of dicts:")
# result5 = df.iloc[0:3].to_dict('records')
# print(result5)
# print(f"Type: {type(result5).__name__}")
# print("\n" + "="*70 + "\n")

# # ===== METHOD 6: Conditional extraction =====
# print("METHOD 6: df[df['age'] > 28] - Extract rows with condition:")
# result6 = df[df['age'] > 28]
# print(result6)
# print("\n" + "="*70 + "\n")

# # ===== METHOD 7: Extract and iterate =====
# print("METHOD 7: Iterate through rows:")
# for idx, row in df.iloc[0:3].iterrows():
#     print(f"Row {idx}: {row.to_dict()}")
# print("\n" + "="*70 + "\n")

# # ===== METHOD 8: itertuples() - faster iteration =====
# print("METHOD 8: Using itertuples() for faster iteration:")
# for row in df.iloc[0:3].itertuples():
#     print(f"Index: {row.Index}, Name: {row.name}, Email: {row.email}")
# print("\n" + "="*70 + "\n")

# # ===== METHOD 9: Extract specific columns from multiple rows =====
# print("METHOD 9: df.iloc[0:3][['name', 'age']] - Select columns from rows:")
# result9 = df.iloc[0:3][['name', 'age']]
# print(result9)
# print("\n" + "="*70 + "\n")

# # ===== METHOD 10: Drop rows =====
# print("METHOD 10: df.drop([1, 3]) - Remove specific rows (keep 0,2,4):")
# result10 = df.drop([1, 3])
# print(result10)
# print("\n" + "="*70 + "\n")

# # ===== METHOD 11: Head and Tail =====
# print("METHOD 11: df.head(2) - Get first 2 rows:")
# print(df.head(2))
# print("\ndf.tail(2) - Get last 2 rows:")
# print(df.tail(2))
# print("\n" + "="*70 + "\n")

# # ===== METHOD 12: Sample rows =====
# print("METHOD 12: df.sample(n=2) - Get random 2 rows:")
# print(df.sample(n=2, random_state=42))
# print("\n" + "="*70 + "\n")

# # ===== SUMMARY =====
# print("SUMMARY - How to Extract Multiple Rows:")
# print("┌─────────────────────────────────────────────────────────┐")
# print("│ Method                 │ Returns  │ Use Case             │")
# print("├─────────────────────────────────────────────────────────┤")
# print("│ df.iloc[0:3]          │ DataFrame│ Position-based range │")
# print("│ df.iloc[[0,2,4]]      │ DataFrame│ Specific indices     │")
# print("│ df.loc[0:2]           │ DataFrame│ Label-based range    │")
# print("│ df.values.tolist()    │ List     │ Convert to nested list")
# print("│ df.to_dict('records') │ List[Dict]│ JSONp-like format   │")
# print("│ df[df['col'] > val]   │ DataFrame│ Conditional filter   │")
# print("│ df.iterrows()         │ Tuples   │ Row-by-row iteration │")
# print("│ df.itertuples()       │ Tuples   │ Faster iteration     │")
# print("│ df.head(n) / tail(n)  │ DataFrame│ First/last n rows    │")
# print("└─────────────────────────────────────────────────────────┘")

# %%
third_row_first_col = f500.iloc[2, 0]
Select the third row, first column by integer location
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable
